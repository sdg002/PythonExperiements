# %% [markdown]
# # About
# Experiments with Diabetes dataset
#
# # imports

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()
diabetes.target[:3]
diabetes.data.shape
# Out:
# (442, 10)

# %%
type(diabetes)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# # Understanding the data structure
# ## What is the type of the downloaded data?

# %%
type(diabetes)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# ## What does the data contain ?
# We can see that there is a `data` element (as though it were a JSON)

# %%
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]], shape=(442, 10)),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %% [markdown]
# ## What is the type of the data element ?

# %%
type(diabetes.data)
# Out:
# numpy.ndarray

# %% [markdown]
# # Visualizing the data using Data Wrangle ?

# %%
arr=diabetes.data

# %% [markdown]
# # Downloading as a dataframe ?
# - The data has 10 columns and 442 rows.
# - The features do not have any names

# %%
diabetes_non_scaled = load_diabetes(scaled=False, as_frame=True)

# %%
type(diabetes_non_scaled.data)
# Out:
# pandas.DataFrame

# %%
df=diabetes_non_scaled.data
df
# Out:
#       age  sex   bmi      bp     s1     s2    s3    s4      s5     s6
# 0    59.0  2.0  32.1  101.00  157.0   93.2  38.0  4.00  4.8598   87.0
# 1    48.0  1.0  21.6   87.00  183.0  103.2  70.0  3.00  3.8918   69.0
# 2    72.0  2.0  30.5   93.00  156.0   93.6  41.0  4.00  4.6728   85.0
# 3    24.0  1.0  25.3   84.00  198.0  131.4  40.0  5.00  4.8903   89.0
# 4    50.0  1.0  23.0  101.00  192.0  125.4  52.0  4.00  4.2905   80.0
# ..    ...  ...   ...     ...    ...    ...   ...   ...     ...    ...
# 437  60.0  2.0  28.2  112.00  185.0  113.8  42.0  4.00  4.9836   93.0
# 438  47.0  2.0  24.9   75.00  225.0  166.0  42.0  5.00  4.4427  102.0
# 439  60.0  2.0  24.9   99.67  162.0  106.6  43.0  3.77  4.1271   95.0
# 440  36.0  1.0  30.0   95.00  201.0  125.2  42.0  4.79  5.1299   85.0
# 441  36.0  1.0  19.6   71.00  250.0  133.2  97.0  3.00  4.5951   92.0
#
# [442 rows x 10 columns]

# %% [markdown]
# # Downloading as X,y

# %%
diabetes_non_scaled_x_y = load_diabetes(scaled=False, return_X_y=True)

# %%
diabetes_non_scaled_x_y
# Out:
# (array([[59.    ,  2.    , 32.1   , ...,  4.    ,  4.8598, 87.    ],
#         [48.    ,  1.    , 21.6   , ...,  3.    ,  3.8918, 69.    ],
#         [72.    ,  2.    , 30.5   , ...,  4.    ,  4.6728, 85.    ],
#         ...,
#         [60.    ,  2.    , 24.9   , ...,  3.77  ,  4.1271, 95.    ],
#         [36.    ,  1.    , 30.    , ...,  4.79  ,  5.1299, 85.    ],
#         [36.    ,  1.    , 19.6   , ...,  3.    ,  4.5951, 92.    ]],
#        shape=(442, 10)),
#  array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#         259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#         128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
# ...
