# %% [markdown]
# # Widget time series

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_raw=pd.read_csv("data/ch04_widget_sales.csv")

# %%
df_raw
# Out:
#      widget_sales
# 0       50.496714
# 1       50.805493
# 2       51.477758
# 3       53.542228
# 4       54.873108
# ..            ...
# 495     64.087371
# 496     63.992081
# 497     63.029894
# 498     61.671797
# 499     59.443839
#
# [500 rows x 1 columns]

# %% [markdown]
# # Raw plot

# %%
fig,ax = plt.subplots()
plt.figure(figsize=(20,8))
ax.set_xlabel("Date")
ax.set_ylabel("Closing price (USD)")
plt.title("Widget sales")

plt.plot(df_raw["widget_sales"])
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Rolling mean plots

# %%
fig,ax = plt.subplots()
plt.figure(figsize=(20,8))
ax.set_xlabel("Date")
ax.set_ylabel("Closing price (USD)")
plt.title("Widget sales")

plt.plot(df_raw["widget_sales"])
plt.plot(df_raw["widget_sales"].rolling(10).mean(), label="Rolling 10", linestyle="solid"  )
plt.plot(df_raw["widget_sales"].rolling(5).mean(), label="Rolling 5", linestyle="dotted"  )
plt.legend()
